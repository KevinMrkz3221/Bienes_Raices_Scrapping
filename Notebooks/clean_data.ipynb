# %%
import pandas as pd

# %%
df = pd.read_csv("./BRdf.csv")
df
# Out:
#      Unnamed: 0                                        Descripcion  \
# 0             0  Casa en Venta en Fracc. Canto de Palermo\nMODE...
# 1             1  Hermoso y privado fraccionamiento a 3 minutos ...
# 2             2  Se vende asa en complejo roma , fracc. Semi pr...
# 3             3  Fraccionamiento privado por zona torres\n\nPeg...
# 4             4  Residencial en venta: campos eliseos\n\ncerca ...
# ..          ...                                                ...
# 582         582  Se vende casa fracc. Oasis revolucion\nMuy gra...
# 583         583              No créditos. EasyBroker ID: EB-CK4912
# 584         584  Se vende  casa fracc. Los nogales , privado\nH...
# 585         585  Se vende casa fracc. Los nogales entre calle e...
# 586         586  Casa en venta: ubicación por haciendas del nog...
#
#                                             Amenidades  \
# 0                                                   []
# ...

# %%
df["Detalles"]
Details = df["Detalles"]
Details
data = []
for detail in Details:
    
    detail = detail.replace("[", "")
    detail = detail.replace("\"", "")
    detail = detail.replace("\\", "")
    detail = detail.replace("\'", "")
    detail = detail.replace("]", "")
    memory = detail.split(",")
    data.append(memory)

# %%
data[0][0][1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_73456/723950985.py in <module>
# ----> 1 data[0][0][1] = 'a'
#
# TypeError: 'str' object does not support item assignment
